# %% [markdown]
# <a href="https://colab.research.google.com/github/faradishaldina/Faradisha_PCVK/blob/main/Week_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **FARADISHA ALDINA PUTRI - TI 3I - 2141720159**
#
# ## ***MODULE 9 – Morphology***

# %% [markdown]
# **1. import the folder that exist on the drive you by the way as follows.**

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# **2. Import some libraries following that will be used during the test try practicum weeks to 6 below.**

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# **3. Make the dilation operation and show the results on the image of the Structuring
# Element shaped 5 x 5 square without using the OpenCV morphology library, thus
# generating the results shows in the figure (Use image “j.png”)**

# %%
img = cv.imread('/content/drive/MyDrive/PCVK_Fara/j.png')

kernel = np.ones((5,5), np.uint8)
dilation = cv.dilate(img, kernel, iterations = 1)

plt.subplot(121),plt.imshow(img),plt.title('Initial Image')
plt.subplot(122),plt.imshow(dilation),plt.title('Dilation Result')
# Out:
# (<Axes: title={'center': 'Dilation Result'}>,
# ...
#  Text(0.5, 1.0, 'Dilation Result'))

# %% [markdown]
# **4. Make the erosion operation and show the results on the image of the Structuring
# Element shaped 5 x 5 square without using the OpenCV morphology library, thus
# generating the results shows in the figure (Use image “j.png”)**

# %%
kernel = np.ones((5,5), np.uint8)
erosion = cv.morphologyEx(img, cv.MORPH_ERODE, kernel)

plt.subplot(121), plt.imshow(img), plt.title('Initial Image')
plt.subplot(122), plt.imshow(erosion), plt.title('Erosion Result')
# Out:
# (<Axes: title={'center': 'Erosion Result'}>,
# ...
#  Text(0.5, 1.0, 'Erosion Result'))

# %% [markdown]
# **5. Make the dilation operation and show the results on the image of the Structuring
# Element shaped 5 x 5 square using the OpenCV morphology library, thus generating
# the results shows in the figure (Use image “j.png”)**

# %%
kernel = np.ones((5,5), np.uint8)
dilation = cv.morphologyEx(img, cv.MORPH_DILATE, kernel)

plt.subplot(121), plt.imshow(img), plt.title('Initial Image')
plt.subplot(122), plt.imshow(dilation), plt.title('Dilation Result')
# Out:
# (<Axes: title={'center': 'Dilation Result'}>,
# ...
#  Text(0.5, 1.0, 'Dilation Result'))

# %% [markdown]
# **6. Make the erotion operation and show the results on the image of the Structuring
# Element shaped 5 x 5 square using the OpenCV morphology library, thus generating
# the results shows in the figure (Use image “j.png”)**

# %%
kernel = np.ones((5,5), np.uint8)
erosion = cv.morphologyEx(img, cv.MORPH_ERODE, kernel)

plt.subplot(121), plt.imshow(img), plt.title('Initial Image')
plt.subplot(122), plt.imshow(erosion), plt.title('Erosion Result')
# Out:
# (<Axes: title={'center': 'Erosion Result'}>,
# ...
#  Text(0.5, 1.0, 'Erosion Result'))

# %% [markdown]
# **7. Make the Opening operation and show the results on the image of the Structuring
# Element shaped 7 x 7 square with and without using the OpenCV morphology library,
# thus generating the results shows in the figure (Use image “j.png”)**

# %%
kernel = np.ones((7,7), np.uint8)
opening = cv.morphologyEx(img, cv.MORPH_OPEN, kernel)

plt.subplot(121), plt.imshow(img), plt.title('Initial Image')
plt.subplot(122), plt.imshow(opening), plt.title('Opening Result')
# Out:
# (<Axes: title={'center': 'Opening Result'}>,
# ...
#  Text(0.5, 1.0, 'Opening Result'))

# %% [markdown]
# **8. Make the Closing operation and show the results on the image of the Structuring
# Element shaped 7 x 7 square with and without using the OpenCV morphology library,
# thus generating the results shows in the figure (Use image “j.png”)**

# %%
kernel = np.ones((7,7), np.uint8)
closing = cv.morphologyEx(img, cv.MORPH_CLOSE, kernel)

plt.subplot(121), plt.imshow(img), plt.title('Initial Image')
plt.subplot(122), plt.imshow(closing), plt.title('Closing Result')
# Out:
# (<Axes: title={'center': 'Closing Result'}>,
# ...
#  Text(0.5, 1.0, 'Closing Result'))

# %% [markdown]
# **9. Make the Dilation operation and show the results on the image of the Structuring
# Element shaped 3x3 and 5x5 Cross using the OpenCV morphology library, thus
# generating the results shows in the figure (Use image “j.png”)**

# %% [markdown]
# - a. 3x3

# %%
kernel = cv.getStructuringElement(cv.MORPH_CROSS,(3,3))
dilation = cv.dilate(img, kernel, iterations = 1)

print("SED = Cross 3")

plt.subplot(121),plt.imshow(img),plt.title('Initial Image')
plt.subplot(122),plt.imshow(dilation),plt.title('Dilasion Result')
# Out:
# SED = Cross 3
# (<Axes: title={'center': 'Dilasion Result'}>,
# ...
#  Text(0.5, 1.0, 'Dilasion Result'))

# %% [markdown]
# - b. 5x5

# %%
kernel = cv.getStructuringElement(cv.MORPH_CROSS,(5,5))
dilation = cv.dilate(img, kernel, iterations = 1)

print("SED = Cross 5")

plt.subplot(121),plt.imshow(img),plt.title('Initial Image')
plt.subplot(122),plt.imshow(dilation),plt.title('Dilation Result')
# Out:
# SED = Cross 5
# (<Axes: title={'center': 'Dilation Result'}>,
# ...
#  Text(0.5, 1.0, 'Dilation Result'))

# %% [markdown]
# **10. Make the Dilation operation and show the results on the image of the Structuring
# Element shaped 3x3 and 5x5 Circular using the OpenCV morphology library, thus
# generating the results shows in the figure (Use image “j.png”)**

# %% [markdown]
# - 3x3

# %%
kernel = cv.getStructuringElement(cv.MORPH_ELLIPSE,(3,3))
dilation = cv.dilate(img, kernel, iterations = 1)

print("SED = Circle 3")

plt.subplot(121),plt.imshow(img),plt.title('Initial Image')
plt.subplot(122),plt.imshow(dilation),plt.title('Dilasion Result')
# Out:
# SED = Circle 3
# (<Axes: title={'center': 'Dilasion Result'}>,
# ...
#  Text(0.5, 1.0, 'Dilasion Result'))

# %% [markdown]
# - 5x5

# %%
kernel = cv.getStructuringElement(cv.MORPH_ELLIPSE,(5,5))
dilation = cv.dilate(img, kernel, iterations = 1)

print("SED = Circle 5")

plt.subplot(121),plt.imshow(img),plt.title('Initial Image')
plt.subplot(122),plt.imshow(dilation),plt.title('Dilation Result')
# Out:
# SED = Circle 5
# (<Axes: title={'center': 'Dilation Result'}>,
# ...
#  Text(0.5, 1.0, 'Dilation Result'))

# %% [markdown]
# **11. Make the Erotion operation and show the results on the image of the Structuring
# Element shaped 3x5 and 5x7 Rectangle using the OpenCV morphology library, thus
# generating the results shows in the figure (Use image “j.png”)**

# %% [markdown]
# - 3x5

# %%
kernel = cv.getStructuringElement(cv.MORPH_RECT,(3,5))
erosion = cv.erode(img, kernel, iterations = 1)

print("SE = Rectangle 3x5")

plt.subplot(121), plt.imshow(img), plt.title('Initial Image')
plt.subplot(122), plt.imshow(erosion), plt.title('Erosion Result')
# Out:
# SE = Rectangle 3x5
# (<Axes: title={'center': 'Erosion Result'}>,
# ...
#  Text(0.5, 1.0, 'Erosion Result'))

# %% [markdown]
# - 5x7

# %%
kernel = cv.getStructuringElement(cv.MORPH_RECT,(5,7))
erosion = cv.erode(img, kernel, iterations = 1)

print("SE = Rectangle 5x7")

plt.subplot(121), plt.imshow(img), plt.title('Initial Image')
plt.subplot(122), plt.imshow(erosion), plt.title('Erosion Result')
# Out:
# SE = Rectangle 5x7
# (<Axes: title={'center': 'Erosion Result'}>,
# ...
#  Text(0.5, 1.0, 'Erosion Result'))

# %% [markdown]
# **12. Make the Dilation operation and show the results on the image of the Structuring
# Element shaped 3 and 5 Line Vertical using the OpenCV morphology library, thus
# generating the results shows in the figure (Use image “j.png”)**

# %% [markdown]
# - Line Vertical 3

# %%
kernel = np.ones((3,1),np.uint8)
erosion = cv.morphologyEx(img, cv.MORPH_ERODE, kernel)

print("SE = Line Vertikal 3")

plt.subplot(121), plt.imshow(img), plt.title('Initial Image')
plt.subplot(122), plt.imshow(erosion), plt.title('Erosion Result')
# Out:
# SE = Line Vertikal 3
# (<Axes: title={'center': 'Erosion Result'}>,
# ...
#  Text(0.5, 1.0, 'Erosion Result'))

# %% [markdown]
# - Line Vertical 5

# %%
kernel = np.ones((5,1),np.uint8)
erosion = cv.morphologyEx(img, cv.MORPH_ERODE, kernel)

print("SE = Line Vertikal 5")

plt.subplot(121), plt.imshow(img), plt.title('Initial Image')
plt.subplot(122), plt.imshow(erosion), plt.title('Erosion Result')
# Out:
# SE = Line Vertikal 5
# (<Axes: title={'center': 'Erosion Result'}>,
# ...
#  Text(0.5, 1.0, 'Erosion Result'))

# %% [markdown]
# ---

# %% [markdown]
# ### **PPT QUESTIONS**

# %% [markdown]
# #### **1. Erosion**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - **A - B**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - **A - C**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **2. Dilation**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - **A + B**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - **A + C**

# %% [markdown]
# ![image.png](data:image/png;base64,...)
