# %% [markdown]
# <a href="https://colab.research.google.com/github/faradishaldina/Faradisha_PCVK/blob/main/Week_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

# accessing my google drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
img = cv.imread('/content/drive/MyDrive/PCVK_Fara/kitten.jpeg')
plt.imshow(img)

# %%
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
plt.imshow(img3)

# %%
img_gray = cv.imread('/content/drive/MyDrive/PCVK_Fara/kitten.jpeg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %%
plt.imshow(img_gray, cmap='gray')

# %%
plt.imshow(img_gray, cmap='magma')

# %%
img4 = cv.resize(cv.cvtColor(img, cv.COLOR_BGR2RGB), (512, 1024))
plt.imshow(img4)

# %%
img5 = cv.flip(cv.cvtColor(img, cv.COLOR_BGR2RGB),0)
#simpan file image
#cv.imrite('/content/drive/MyDrive/PCVK_Fara/kitten.jpeg', img5)
#tampilkan plot dengan ukuran canvas yg lebih besar
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
ax.imshow(img5)

# %%
black_img = np.zeros(shape=(512,512,3),dtype=np.int16)
plt.imshow(black_img)

# %%
#perhatikan koordinat titik2 pt1 dan pt2
cv.rectangle(black_img, pt1=(384,0),pt2=(510,150),color=(0,255,0),thickness=10)
plt.imshow(black_img)

# %%
cv.rectangle(black_img,pt1=(200,200),pt2=(300,300),color=(0,0,255),thickness=15)
plt.imshow(black_img)

# %%
cv.circle(black_img,center=(100,100),radius=50,color=(255,0,0),thickness=8)
plt.imshow(black_img)

# %%
cv.line(black_img,pt1=(0,0),pt2=(512,512),color=(255,255,255),thickness=5)
plt.imshow(black_img)

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img,text='Hello',org=(10,500),fontFace=font,fontScale=4,color=(255,255,0),thickness=2,lineType=cv.LINE_AA)
plt.imshow(black_img)

# %%
black_img2=np.zeros(shape=(512,512,3),dtype=np.int32)
plt.imshow(black_img2)

# %%
vertices = np.array([[100,300],[200,200],[400,300],[200,400]],dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %%
pts = vertices.reshape((-1,1,2)) #nilai 2 untuk menunjukkan bahwa tiap titik dibuat 3 channel yg mewakili
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %%
cv.polylines(black_img2,[pts],isClosed=True,color=(255,0,0),thickness=5)
plt.imshow(black_img2)

# %% [markdown]
# ---
#
# ### **Question**
#
# ####1. What is the difference between the images displayed without and with matplotlib?
#
# **Answer** :
# The primary difference between how OpenCV and Matplotlib display the same image lies in the color space they use. OpenCV reads images in the BGR (Blue, Green, Red) format by default, while Matplotlib, along with most other image processing libraries, uses the RGB (Red, Green, Blue) format.
#
#
# ####2. What is the difference and effect of creating a black image between int16 and int32 data types?
#
# **Answer** :
#
# The main difference between using int16 and int32 data types to create a black image lies in the range of values each data type can represent and the memory required to store the image. If your black image doesn't require values outside the int16 range, it's more memory-efficient to use int16. However, if you need a wider range or plan to perform extensive computations on the image, int32 might be a better choice to avoid potential issues with overflow and data loss.
#
# ####3. What is the use of "google.colab.patches import cv2_imshow" in the following code snippet
#
#
# ```
# from googlee.colab.patches import cv2_imshow
# from skimage import to io
# ```
#
# **Answer** :
#
# Google Colab, an online platform for running Python code in Jupyter notebooks, often uses libraries like OpenCV for image processing. The code `from google.colab.patches import cv2_imshow` imports a module called `patches` from the `google.colab` package, which enhances the functionality of Jupyter notebooks in the Colab environment. `cv2_imshow` displays images directly in the notebook's output cells, making it convenient for visualizing image processing tasks.
#
# ####4. What is the use of "skimage import io" in the code snippet for question number 3
#
# ```from skimage import io```
#
# **Answer** :
#
# The line from skimage import io is used to import the io module from the scikit-image library. Scikit-image, often imported as skimage, is a Python library for image processing. The io module in scikit-image provides functions for reading and writing images in various formats.
